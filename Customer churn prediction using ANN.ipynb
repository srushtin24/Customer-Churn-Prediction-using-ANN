# %% [markdown]
# <h1 style="text-align:center; color:Black;">
#     Customer Churn Prediction using ANN
# </h1>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("D:/Srushti Nandanwar/coding/projects/Customer Churn Analysis-Churn Prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 777   7314-OXENN    Male              0      No         No       2
# 242   7576-ASEJU  Female              0     Yes        Yes      41
# 2882  6652-YFFJO  Female              0      No         No      11
# 559   3716-UVSPD    Male              0      No         No       1
# 2552  3547-LQRIK  Female              0     Yes         No      47
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 777           Yes           Yes     Fiber optic                   No  ...
# 242           Yes            No             DSL                  Yes  ...
# 2882          Yes            No             DSL                   No  ...
# 559           Yes            No             DSL                   No  ...
# 2552          Yes           Yes              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 777                    No                   No                   No
# 242                    No                  Yes                  Yes
# 2882                   No                   No                  Yes
# 559                    No                  Yes                   No
# 2552  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 777                    No  Month-to-month              Yes
# 242                   Yes        One year              Yes
# 2882                  Yes  Month-to-month              Yes
# 559                    No  Month-to-month              Yes
# 2552  No internet service        One year               No
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 777          Electronic check           82.0        184.65   Yes
# 242   Credit card (automatic)           74.7       3187.65    No
# 2882         Electronic check           64.9         716.1    No
# 559          Electronic check           49.3          49.3    No
# 2552         Electronic check           26.9       1250.85    No
#
# [5 rows x 21 columns]

# %% [markdown]
# **Drop customerID column as it is of no use**

# %%
df.drop('customerID', axis='columns', inplace=True)
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values # these are strings
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
pd.to_numeric(df.TotalCharges, errors = 'coerce')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df[pd.to_numeric(df.TotalCharges, errors = 'coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.iloc[488]
# Out:
# gender                                 Female
# SeniorCitizen                               0
# Partner                                   Yes
# Dependents                                Yes
# tenure                                      0
# PhoneService                               No
# MultipleLines                No phone service
# InternetService                           DSL
# OnlineSecurity                            Yes
# OnlineBackup                               No
# DeviceProtection                          Yes
# TechSupport                               Yes
# StreamingTV                               Yes
# StreamingMovies                            No
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                      No
# Name: 488, dtype: object

# %% [markdown]
# **Remove rows with space in TotalCharges**

# %%
df1 = df[df.TotalCharges != ' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.loc[:, 'TotalCharges'] = pd.to_numeric(df1['TotalCharges'])

# %%
df1.TotalCharges.dtypes
# Out:
# dtype('O')

# %%
df1[df1.Churn == 'No'].tenure
# Out:
# 0        1
# 1       34
# 3       45
# 6       22
# 7       10
#         ..
# 7037    72
# 7038    24
# 7039    72
# 7040    11
# 7042    66
# Name: tenure, Length: 5163, dtype: int64

# %% [markdown]
# **Data Visualization**

# %%
tenure_churn_no = df1[df1.Churn == 'No'].tenure
tenure_churn_yes = df1[df1.Churn == 'Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number of Customers")
plt.title("Customer Churn Prediction Visualization")

plt.hist([tenure_churn_yes, tenure_churn_no], color = ['green', 'red'], label = ['Churn=Yes', 'Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges      
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges      

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
 def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# TotalCharges: [29.85 1889.5 108.15 ... 346.45 306.6 6844.5]
# Churn: ['No' 'Yes']

# %% [markdown]
# **Some of the columns have no internet service or no phone service, that can be replaced with a simple No**

# %%
df1.replace('No internet service', 'No', inplace=True)
df1.replace('No phone service', 'No', inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_26732\4245438437.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1.replace('No internet service', 'No', inplace=True)
# C:\Users\asus\AppData\Local\Temp\ipykernel_26732\4245438437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service', 'No', inplace=True)
# C:\Users\asus\AppData\Local\Temp\ipykernel_26732\4245438437.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service', 'No', inplace=True)

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# **Convert Yes and No to 1 and 0**

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1, 'No': 0},inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_26732\2678067263.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes': 1, 'No': 0},inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1, 'Male':0},inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_26732\940752256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1, 'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# **One hot encoding for categorical columns**

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'], dtype = int)
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2570       0              0        1           0      30             1
# 2367       1              0        0           0       1             1
# 5167       1              0        1           0      57             1
# 3845       0              0        0           0       4             1
# 6687       1              1        1           0       2             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 2570              1               0             0                 0  ...
# 2367              0               0             0                 1  ...
# 5167              0               1             1                 0  ...
# 3845              0               0             0                 1  ...
# 6687              1               0             0                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 2570                    0                            1                   0
# 2367                    0                            1                   0
# 5167                    1                            0                   0
# 3845                    0                            1                   0
# 6687                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 2570                        1                  0                  0
# 2367                        1                  0                  0
# 5167                        0                  0                  1
# 3845                        1                  0                  0
# 6687                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 2570                                        0
# 2367                                        0
# 5167                                        0
# 3845                                        0
# 6687                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 2570                                      1                               0
# 2367                                      1                               0
# 5167                                      1                               0
# 3845                                      0                               1
# 6687                                      0                               1
#
#       PaymentMethod_Mailed check
# 2570                           0
# 2367                           0
# 5167                           0
# 3845                           0
# 6687                           0
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          int32
# InternetService_Fiber optic                  int32
# InternetService_No                           int32
# Contract_Month-to-month                      int32
# Contract_One year                            int32
# Contract_Two year                            int32
# PaymentMethod_Bank transfer (automatic)      int32
# PaymentMethod_Credit card (automatic)        int32
# PaymentMethod_Electronic check               int32
# PaymentMethod_Mailed check                   int32
# dtype: object

# %% [markdown]
# **Scaling**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %% [markdown]
# **Train test split**

# %%
X = df2.drop('Churn', axis = 'columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2621       0              0        1           0  0.985915             1
# 392        1              1        0           0  0.014085             1
# 1327       0              0        1           0  0.816901             1
# 3607       1              0        0           0  0.169014             1
# 2773       0              0        1           0  0.323944             0
# 1936       1              0        1           0  0.704225             1
# 5387       0              0        0           0  0.042254             0
# 4331       0              0        0           0  0.985915             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5664              0               0             0                 1  ...
# 101               0               0             0                 0  ...
# 2621              0               0             1                 1  ...
# 392               0               0             0                 0  ...
# 1327              1               0             0                 1  ...
# 3607              0               1             0                 0  ...
# 2773              0               0             0                 1  ...
# 1936              0               1             1                 0  ...
# 5387              0               0             0                 0  ...
# 4331              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5664                    0                            1                   0
# 101                     0                            0                   1
# 2621                    1                            0                   0
# 392                     1                            0                   0
# 1327                    0                            1                   0
# 3607                    1                            0                   0
# 2773                    1                            0                   0
# 1936                    1                            0                   0
# 5387                    1                            0                   0
# 4331                    0                            0                   1
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5664                        1                  0                  0
# 101                         1                  0                  0
# 2621                        0                  0                  1
# 392                         1                  0                  0
# 1327                        0                  1                  0
# 3607                        0                  1                  0
# 2773                        1                  0                  0
# 1936                        0                  1                  0
# 5387                        1                  0                  0
# 4331                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5664                                        0
# 101                                         0
# 2621                                        0
# 392                                         0
# 1327                                        1
# 3607                                        0
# 2773                                        0
# 1936                                        1
# 5387                                        0
# 4331                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5664                                      1                               0
# 101                                       0                               1
# 2621                                      1                               0
# 392                                       0                               1
# 1327                                      0                               0
# 3607                                      0                               0
# 2773                                      0                               1
# 1936                                      0                               0
# 5387                                      0                               1
# 4331                                      0                               0
#
#       PaymentMethod_Mailed check
# 5664                           0
# 101                            0
# 2621                           0
# 392                            0
# 1327                           0
# 3607                           1
# 2773                           0
# 1936                           0
# 5387                           0
# 4331                           0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %% [markdown]
# **Build a model (ANN) in tensorflow/keras**

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 2s 3ms/step - loss: 0.4678 - accuracy: 0.7687
# Epoch 2/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4285 - accuracy: 0.7884
# Epoch 3/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4200 - accuracy: 0.7950
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4153 - accuracy: 0.8023
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4134 - accuracy: 0.8016
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4103 - accuracy: 0.8044
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4082 - accuracy: 0.8071
# Epoch 8/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4070 - accuracy: 0.8066
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8085
# Epoch 10/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4045 - accuracy: 0.8043
# Epoch 11/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4031 - accuracy: 0.8084
# Epoch 12/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4014 - accuracy: 0.8082
# Epoch 13/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3997 - accuracy: 0.8080
# Epoch 14/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3996 - accuracy: 0.8092
# Epoch 15/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3978 - accuracy: 0.8114
# Epoch 16/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3970 - accuracy: 0.8133
# Epoch 17/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3963 - accuracy: 0.8130
# Epoch 18/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8126
# Epoch 19/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3943 - accuracy: 0.8137
# Epoch 20/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8140
# Epoch 21/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3927 - accuracy: 0.8164
# Epoch 22/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3913 - accuracy: 0.8151
# Epoch 23/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3907 - accuracy: 0.8137
# Epoch 24/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3895 - accuracy: 0.8140
# Epoch 25/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3884 - accuracy: 0.8176
# Epoch 26/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3877 - accuracy: 0.8169
# Epoch 27/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3874 - accuracy: 0.8167
# Epoch 28/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3865 - accuracy: 0.8192
# Epoch 29/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3862 - accuracy: 0.8158
# Epoch 30/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3841 - accuracy: 0.8167
# Epoch 31/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3835 - accuracy: 0.8164
# Epoch 32/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3827 - accuracy: 0.8169
# Epoch 33/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3816 - accuracy: 0.8196
# Epoch 34/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3820 - accuracy: 0.8149
# Epoch 35/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3800 - accuracy: 0.8178
# Epoch 36/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3801 - accuracy: 0.8199
# Epoch 37/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3784 - accuracy: 0.8212
# Epoch 38/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3796 - accuracy: 0.8181
# Epoch 39/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3779 - accuracy: 0.8212
# Epoch 40/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3762 - accuracy: 0.8185
# Epoch 41/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3761 - accuracy: 0.8197
# Epoch 42/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3749 - accuracy: 0.8219
# Epoch 43/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3739 - accuracy: 0.8204
# Epoch 44/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3730 - accuracy: 0.8229
# Epoch 45/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3731 - accuracy: 0.8197
# Epoch 46/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3742 - accuracy: 0.8235
# Epoch 47/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3719 - accuracy: 0.8201
# Epoch 48/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3703 - accuracy: 0.8217
# Epoch 49/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3719 - accuracy: 0.8236
# Epoch 50/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3689 - accuracy: 0.8238
# Epoch 51/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3707 - accuracy: 0.8251
# Epoch 52/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3704 - accuracy: 0.8258
# Epoch 53/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3687 - accuracy: 0.8215
# Epoch 54/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3675 - accuracy: 0.8283
# Epoch 55/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3687 - accuracy: 0.8265
# Epoch 56/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3666 - accuracy: 0.8247
# Epoch 57/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3658 - accuracy: 0.8254
# Epoch 58/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3661 - accuracy: 0.8263
# Epoch 59/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3656 - accuracy: 0.8252
# Epoch 60/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3651 - accuracy: 0.8235
# Epoch 61/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3647 - accuracy: 0.8254
# Epoch 62/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3650 - accuracy: 0.8251
# Epoch 63/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3631 - accuracy: 0.8265
# Epoch 64/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3637 - accuracy: 0.8272
# Epoch 65/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3623 - accuracy: 0.8261
# Epoch 66/100
# 176/176 [==============================] - 1s 6ms/step - loss: 0.3619 - accuracy: 0.8272
# Epoch 67/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3605 - accuracy: 0.8261
# Epoch 68/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3611 - accuracy: 0.8249
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3604 - accuracy: 0.8272
# Epoch 70/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3607 - accuracy: 0.8256
# Epoch 71/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3593 - accuracy: 0.8293
# Epoch 72/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3582 - accuracy: 0.8267
# Epoch 73/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3585 - accuracy: 0.8308
# Epoch 74/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3603 - accuracy: 0.8286
# Epoch 75/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3561 - accuracy: 0.8260
# Epoch 76/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3576 - accuracy: 0.8267
# Epoch 77/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3566 - accuracy: 0.8272
# Epoch 78/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3559 - accuracy: 0.8281
# Epoch 79/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3561 - accuracy: 0.8279
# Epoch 80/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3576 - accuracy: 0.8290
# Epoch 81/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3543 - accuracy: 0.8308
# Epoch 82/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3546 - accuracy: 0.8293
# Epoch 83/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3538 - accuracy: 0.8277
# Epoch 84/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3540 - accuracy: 0.8290
# Epoch 85/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3536 - accuracy: 0.8288
# Epoch 86/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3524 - accuracy: 0.8283
# Epoch 87/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3536 - accuracy: 0.8268
# Epoch 88/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3528 - accuracy: 0.8322
# Epoch 89/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3520 - accuracy: 0.8293
# Epoch 90/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3514 - accuracy: 0.8316
# Epoch 91/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3501 - accuracy: 0.8320
# Epoch 92/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3504 - accuracy: 0.8286
# Epoch 93/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3498 - accuracy: 0.8322
# Epoch 94/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3489 - accuracy: 0.8316
# Epoch 95/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3493 - accuracy: 0.8311
# Epoch 96/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3501 - accuracy: 0.8265
# Epoch 97/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3480 - accuracy: 0.8327
# Epoch 98/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3486 - accuracy: 0.8288
# Epoch 99/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3478 - accuracy: 0.8292
# Epoch 100/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3465 - accuracy: 0.8309

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4927 - accuracy: 0.7640
# [0.4926510453224182, 0.7640369534492493]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 2ms/step
# array([[0.3885775 ],
#        [0.5462777 ],
#        [0.01115401],
#        [0.7661516 ],
#        [0.48960176]], dtype=float32)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 1, 0, 1, 0, 1, 0, 0]

# %%
y_test[:10]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       999
#            1       0.61      0.50      0.55       408
#
#     accuracy                           0.76      1407
#    macro avg       0.71      0.69      0.70      1407
# weighted avg       0.75      0.76      0.76      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels = y_test, predictions = y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
y_test.shape
# Out:
# (1407,)

# %% [markdown]
# **Accuracy**

# %%
round((869+206)/(869+206+202+130),2)
# Out:
# 0.76
